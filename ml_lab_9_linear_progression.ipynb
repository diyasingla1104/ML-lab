# %% [markdown]
# <a href="https://colab.research.google.com/github/diyasingla1104/ML-lab/blob/main/ml_lab_9_linear_progression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Given data
x = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y = np.array([2, 4, 8, 16, 24])

# Create and train the model
model = LinearRegression()
model.fit(x, y)

# Predict y for x = 6
x_pred = np.array([[6]])
y_pred = model.predict(x_pred)

print(f"Predicted value of y at x=6: {y_pred[0]}")

# Calculate MSE and RMSE
y_pred_train = model.predict(x)
mse = mean_squared_error(y, y_pred_train)
rmse = np.sqrt(mse)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")

# Plot the data and regression line
plt.scatter(x, y, color='blue', label='Original Data')
plt.plot(x, model.predict(x), color='red', label='Regression Line')
plt.scatter(x_pred, y_pred, color='green', marker='x', s=100, label='Prediction at x=6')
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()
# Out:
# Predicted value of y at x=6: 27.600000000000005
# Mean Squared Error (MSE): 3.8400000000000007
# Root Mean Squared Error (RMSE): 1.9595917942265426
